# %% [markdown]
# # TUGAS4

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from matplotlib import pyplot
X_test, y_test = make_regression(n_samples=20, n_features=1, noise=10)
reg = LinearRegression().fit(X_test, y_test)
reg.score(X_test, y_test)

reg.coef_

reg.intercept_

reg.predict(np.array([[3]]))
# Out:
# array([240.80350116])

# %%
x=X_test.tolist()
y=y_test.tolist()

# %%
import pandas as pd
data = {'X':x,
        'Y':y}

df = pd.DataFrame(data)

# %%
df.head(20)
# Out:
#                          X           Y
# 0    [-0.6922908241278193]  -39.780236
# 1    [-0.4467731566942439]  -37.728471
# 2   [-0.11034790099095536]   -9.906869
# 3     [0.2688865436297284]   19.048394
# 4    [-0.6231609519748775]  -57.016424
# 5    [-0.7412329710728796]  -65.218479
# 6    [-0.4747084811953326]  -16.768275
# 7    [-0.4666457341201413]  -24.128166
# 8     [0.4517482403785449]   25.804847
# 9     [1.2569173364346753]   95.654687
# 10    [0.9657711412270191]   95.786721
# 11    [1.9386667864781433]  145.263184
# 12     [0.509273576265279]   58.830051
# 13   [0.27736312470858293]   20.440232
# 14   [-0.4773640765653581]  -46.076758
# 15   [0.38321157803818556]   42.582268
# 16    [0.9703671598404563]   68.385193
# 17  [-0.14730188060035942]   -6.724033
# 18    [-1.425784996152194] -126.709212
# 19   [-0.5435544772304619]  -51.666682

# %%
reg.coef_
# Out:
# array([79.92966414])

# %%
reg.intercept_
# Out:
# 1.014508749605096

# %%
pyplot.scatter(X_test,y_test)
Y_plot = reg.coef_*X_test+reg.intercept_

pyplot.plot(X_test, Y_plot, color='r')

pyplot.show()
